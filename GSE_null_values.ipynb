# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %%
prefix = '/data4/mankovic/GSE73072/network_centrality/simple_rankings/2-4hr/ssvm/gse73072_'
out_prefix = '/data4/mankovic/GSE73072/network_centrality/simple_rankings/null_values/2-4hr/ssvm/'
directed = 'directed'
centrality_type = 'degree'
best_measure = 'unnormalized'
n_null_trials = 100
epsilon = .00001
alpha = .05

# %%
x = pandas.read_csv(prefix+directed+'_'+centrality_type+'.csv')[:-1]
x
# Out:
#                     pathway_id  unnormalized  path norm  feature path norm  \
# 0      pw_mtx_R-HSA-109582.csv          28.0   0.082353           7.000000
# 1      pw_mtx_R-HSA-114608.csv           2.0   0.029851           2.000000
# 2      pw_mtx_R-HSA-168249.csv          78.0   0.129784           5.200000
# 3      pw_mtx_R-HSA-168256.csv         237.0   0.210293           7.900000
# 4     pw_mtx_R-HSA-6798695.csv          19.0   0.070896           2.111111
# ...                        ...           ...        ...                ...
# 2009  pw_mtx_R-HSA-1222538.csv           0.0   0.000000                NaN
# 2010  pw_mtx_R-HSA-1222541.csv           0.0   0.000000                NaN
# 2011  pw_mtx_R-HSA-1222387.csv           0.0   0.000000                NaN
# 2012  pw_mtx_R-HSA-9637628.csv           0.0   0.000000                NaN
# 2013  pw_mtx_R-HSA-9635644.csv           0.0   0.000000                NaN
#
#       max degree norm  feature path count  path count
# 0            0.682927                   4         340
# 1            0.333333                   1          67
# 2            1.344828                  15         601
# 3            1.612245                  30        1127
# 4            1.461538                   9         268
# ...               ...                 ...         ...
# 2009              NaN                   0          11
# 2010              NaN                   0           8
# 2011              NaN                   0          11
# 2012              NaN                   0           4
# 2013              NaN                   0           2
#
# [2014 rows x 7 columns]

# %%
ys = []

y = pandas.read_csv(prefix+directed+'_'+centrality_type+'_null0.csv')[:-1]
ys.append(y)
pids  = list(y['pathway_id'])
ax = y.plot.scatter('max degree norm', 'path count', color = 'orange', alpha = .5)

ax.set_yscale('log')
ax.set_xscale('log')
for i in range(1,n_null_trials):
    y = pandas.read_csv(prefix+directed+'_'+centrality_type+'_null'+str(i)+'.csv')[:-1]
    ys.append(y)
    y.plot.scatter('max degree norm', 'path count', ax = ax, color = 'orange', alpha = .5, marker = 'x')
    pids += list(y['pathway_id'])
pids = np.unique(pids)
    # print(len(y))
x.plot.scatter('max degree norm','path count', ax = ax)
# Out:
# <AxesSubplot:xlabel='max degree norm', ylabel='path count'>

# %%
# ys = []
# pids = list(x['pathway_id'])
# for i in range(50):
#     y = pandas.read_csv(prefix+'null'+str(i)+'heatkernel_degree.csv')[:-1]
#     ys.append(y)
#     print(len(y))
#     pids+= list(y['pathway_id'])
# pids = np.unique(pids)

# %%
len(pids)
# Out:
# 2014

# %%
jj=0
for p in pids:
    for i in range(n_null_trials):
        y = ys[i]
        if p not in list(y['pathway_id']):
            p_dict = {'pathway_id':p, 
          'unnormalized':0, 
          'path norm':0, 
          'feature path norm':0, 
          'avg degree norm':0, 
          'max degree norm':0, 
          'feature path count':0,
          'path count': np.nan}
            y = y.append(p_dict, ignore_index=True)
        ys[i] = y
    jj+=1
    if jj %100 == 0:
        print(100*jj/len(pids))
# Out:
# 4.965243296921549
# 9.930486593843098
# 14.895729890764647
# 19.860973187686195
# 24.826216484607745
# 29.791459781529294
# 34.75670307845085
# 39.72194637537239
# 44.68718967229394
# 49.65243296921549
# 54.61767626613704
# 59.58291956305859
# 64.54816285998014
# 69.5134061569017
# 74.47864945382324
# 79.44389275074478
# 84.40913604766634
# 89.37437934458788
# 94.33962264150944
# 99.30486593843098

# %%
for y in ys:
    print(len(y))
# Out:
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014

# %%
jj=0
for p in pids:

    if p not in list(x['pathway_id']):
        p_dict = {'pathway_id':p, 
      'unnormalized':0, 
      'path norm':0, 
      'feature path norm':0, 
      'avg degree norm':0, 
      'max degree norm':0, 
      'feature path count':0,
      'path count': np.nan}
        x = x.append(p_dict, ignore_index=True)

    jj+=1
    if jj %100 == 0:
        print(100*jj/len(pids))
# Out:
# 4.965243296921549
# 9.930486593843098
# 14.895729890764647
# 19.860973187686195
# 24.826216484607745
# 29.791459781529294
# 34.75670307845085
# 39.72194637537239
# 44.68718967229394
# 49.65243296921549
# 54.61767626613704
# 59.58291956305859
# 64.54816285998014
# 69.5134061569017
# 74.47864945382324
# 79.44389275074478
# 84.40913604766634
# 89.37437934458788
# 94.33962264150944
# 99.30486593843098

# %%
len(x)
# Out:
# 2014

# %%
x = x.sort_values('pathway_id')
x[best_measure] = np.array(x[best_measure])/np.linalg.norm(np.array(x[best_measure]))
for i in range(len(ys)):
    ys[i] = ys[i].sort_values('pathway_id')
    ys[i][best_measure] = np.array(ys[i][best_measure])/np.linalg.norm(np.array(ys[i][best_measure]))

# %%
x
# Out:
#                     pathway_id  unnormalized  path norm  feature path norm  \
# 1695  pw_mtx_R-HSA-1059683.csv      0.000000   0.000000                NaN
# 21     pw_mtx_R-HSA-109581.csv      0.000000   0.000000                NaN
# 0      pw_mtx_R-HSA-109582.csv      0.026003   0.082353                7.0
# 22     pw_mtx_R-HSA-109606.csv      0.000000   0.000000                NaN
# 1021   pw_mtx_R-HSA-109704.csv      0.016716   0.782609                9.0
# ...                        ...           ...        ...                ...
# 1051   pw_mtx_R-HSA-983695.csv      0.000000   0.000000                NaN
# 432    pw_mtx_R-HSA-983705.csv      0.000000   0.000000                NaN
# 256    pw_mtx_R-HSA-983712.csv      0.000929   0.008475                1.0
# 935    pw_mtx_R-HSA-991365.csv      0.000000   0.000000                NaN
# 1569   pw_mtx_R-HSA-997272.csv      0.000000   0.000000                NaN
#
#       max degree norm  feature path count  path count
# 1695         0.000000                   0           7
# 21           0.000000                   0          90
# 0            0.682927                   4         340
# 22           0.000000                   0          33
# 1021         1.285714                   2          23
# ...               ...                 ...         ...
# 1051         0.000000                   0          18
# 432          0.000000                   0          54
# 256          0.062500                   1         118
# 935          0.000000                   0          10
# 1569         0.000000                   0           5
#
# [2014 rows x 7 columns]

# %%
ax = ys[0].plot.scatter('pathway_id', best_measure, color = 'orange', alpha = .5, marker = 'x')
for i in range(1,n_null_trials):
    ys[i].plot.scatter('pathway_id', best_measure, ax = ax, color = 'orange', alpha = .5, marker = 'x')
x.plot.scatter('pathway_id', best_measure, ax = ax)
# Out:
# <AxesSubplot:xlabel='pathway_id', ylabel='unnormalized'>

# %%
null_array = np.vstack([np.array(y[best_measure])for y in ys])
test_array = np.array(x[best_measure])

# %%
# bigger_than_std_pid = list(x['pathway_id'][np.where(np.abs(np.mean(null_array, axis = 0) - test_array) > np.std(null_array, axis= 0))[0]])

# len(bigger_than_std_pid)

# %%
#statistical significance by the CePa Paper
bigger_genes = np.zeros(null_array.shape)
for i in range(n_null_trials):
    idx = np.where(test_array < null_array[i,:])
    bigger_genes[i, idx] = 1
    
p_val = np.mean(bigger_genes, axis = 0)

x['p_val'] = p_val

# %%
x.to_csv(out_prefix+directed+'_'+centrality_type+'_100null.csv')

# %%
plt.scatter(x[best_measure], x['p_val'])
plt.xscale('log')
plt.yscale('log')
plt.xlabel(best_measure)
plt.ylabel('p_val')
# Out:
# Text(0, 0.5, 'p_val')

# %%
#.05 for correlation, degree
#.1 for heatkernel, degree

out = x.query('p_val < @epsilon and `{0}` > @alpha'.format(best_measure)).sort_values(best_measure, ascending = False)[['pathway_id', best_measure, 'p_val', 'feature path count', 'path count']]
print(len(out))

out.to_csv(centrality_type+'_'+directed+'_'+str(epsilon)+'_'+str(alpha)+'.csv')

# idx = list(set(np.where(p_val < epsilon)[0]).intersection(set(np.where(test_array > alpha)[0])))
# x.iloc[idx].sort_values(best_measure)[['pathway_id',best_measure, 'feature path count', 'path count']]
# Out:
# 19

# %%
out
# Out:
#                     pathway_id  unnormalized  p_val  feature path count  \
# 3      pw_mtx_R-HSA-168256.csv      0.389511    0.0                  30
# 30     pw_mtx_R-HSA-162582.csv      0.389465    0.0                  30
# 27    pw_mtx_R-HSA-1280215.csv      0.194983    0.0                  15
# 2      pw_mtx_R-HSA-168249.csv      0.194876    0.0                  15
# 19     pw_mtx_R-HSA-597592.csv      0.194840    0.0                  15
# 368    pw_mtx_R-HSA-913531.csv      0.130457    0.0                  10
# 4     pw_mtx_R-HSA-6798695.csv      0.117124    0.0                   9
# 677    pw_mtx_R-HSA-909733.csv      0.079089    0.0                   6
# 1141  pw_mtx_R-HSA-1169410.csv      0.078884    0.0                   6
# 353   pw_mtx_R-HSA-1474244.csv      0.078487    0.0                   6
# 869   pw_mtx_R-HSA-1474290.csv      0.065876    0.0                   5
# 626    pw_mtx_R-HSA-163125.csv      0.065590    0.0                   5
# 367    pw_mtx_R-HSA-877300.csv      0.053191    0.0                   4
# 1125  pw_mtx_R-HSA-2022090.csv      0.053093    0.0                   4
# 42    pw_mtx_R-HSA-2219528.csv      0.052968    0.0                   4
# 272   pw_mtx_R-HSA-1630316.csv      0.052417    0.0                   4
# 121     pw_mtx_R-HSA-71387.csv      0.052158    0.0                   4
# 850    pw_mtx_R-HSA-425407.csv      0.051898    0.0                   4
# 1404  pw_mtx_R-HSA-8983711.csv      0.051898    0.0                   4
#
#       path count
# 3           1127
# 30          1486
# 27           386
# 2            601
# 19           787
# 368          110
# 4            268
# 677           36
# 1141          46
# 353          182
# 869           71
# 626           55
# 367           41
# 1125          51
# 42            54
# 272           61
# 121          172
# 850          143
# 1404           6

# %%
for i in range(n_null_trials):
    y_query = ys[i][ys[i]['pathway_id'].isin(list(out['pathway_id']))]
    plt.scatter(y_query['pathway_id'],y_query[best_measure], color = 'tab:orange', alpha = .5)
plt.scatter(out['pathway_id'], out[best_measure], color= 'tab:blue')

# %% [markdown]
# # For Eric Results

# %%
prefix = '../pathway_ranking/Z42_featureset2/Z42_pathway_scores_'
sim_type = 'correlation'
centrality_type = 'degree'
epsilon = .00001
alpha = .05
out = pandas.read_csv(centrality_type+'_'+sim_type+'_'+str(epsilon)+'_'+str(alpha)+'.csv')
out = out.sort_values('max degree norm', ascending = False)
out
# Out:
#     Unnamed: 0 pathway_id  max degree norm  p_val  feature path count  \
# 12           7     p_1050         0.186178    0.0                  14
# 11          16      p_174         0.144955    0.0                  10
# 10          28      p_803         0.106147    0.0                   7
# 9           22     p_2067         0.104568    0.0                   7
# 8           78      p_206         0.076730    0.0                   5
# 7           72       p_70         0.070320    0.0                   5
# 6           83     p_2169         0.069994    0.0                   5
# 5           68     p_1270         0.069432    0.0                   5
# 4           57      p_614         0.060096    0.0                   5
# 3           79     p_1273         0.059779    0.0                   4
# 2          115       p_94         0.056070    0.0                   4
# 1           84     p_2365         0.055027    0.0                   4
# 0           80      p_143         0.054369    0.0                   4
#
#     path count
# 12       749.0
# 11       368.0
# 10       225.0
# 9        264.0
# 8         74.0
# 7        105.0
# 6         65.0
# 5        103.0
# 4        147.0
# 3         91.0
# 2         47.0
# 1         79.0
# 0         92.0

# %%
all_out = pandas.DataFrame(columns = ['correlation_degree', 'correlation_page_rank', 'heatkernel_degree', 'heatkernel_page_rank', 'n_features']+['rid_'+str(i) for i in range(40)])

# %%
pathway_data = pandas.read_csv('/data4/mankovic/De-Identified_CZ/deidentified_fcpw_updated.csv')
pathway_data = pathway_data.fillna(0)

Z42_features = pandas.read_csv('/data4/mankovic/De-Identified_CZ/z42_features_after_hyperparameter_search.csv', index_col = 0)
featureset_randIDs = [str(r) for r in list(Z42_features.index)]

featureset_randIDs
# Out:
# ['10158',
#  '10179',
#  '10414',
#  '10505',
#  '10540',
#  '10621',
#  '10627',
#  '10716',
#  '10814',
#  '10921',
#  '10935',
#  '10961',
#  '10966',
#  '11015',
#  '11074',
#  '11141',
#  '1121',
#  '11245',
#  '11260',
#  '11474',
#  '11556',
#  '11604',
#  '1171',
#  '11770',
#  '11794',
#  '11849',
#  '1189',
#  '11929',
#  '11971',
#  '1204',
#  '12134',
#  '12175',
#  '12201',
#  '12204',
#  '12239',
#  '12371',
#  '12528',
#  '12531',
#  '1255',
#  '12725',
#  '12866',
#  '12908',
#  '13008',
#  '13057',
#  '13099',
#  '13258',
#  '13311',
#  '13436',
#  '13491',
#  '13614',
#  '13619',
#  '13726',
#  '13836',
#  '13861',
#  '13884',
#  '13941',
#  '13985',
#  '14049',
#  '14194',
#  '1437',
#  '14401',
#  '14479',
#  '14517',
#  '14531',
#  '14584',
#  '14595',
#  '14612',
#  '14643',
#  '14715',
#  '14723',
#  '14789',
#  '14850',
#  '14900',
#  '15003',
#  '15008',
#  '15016',
#  '15022',
#  '1511',
#  '7883',
#  '7899',
#  '7910',
#  '8065',
#  '8196',
#  '8244',
#  '8367',
#  '8376',
#  '8388',
#  '8460',
#  '8534',
#  '857',
#  '882',
#  '8832',
#  '8859',
#  '8901',
#  '8917',
#  '8950',
#  '8954',
#  '8992',
#  '9034',
#  '919',
#  '9251',
#  '9331',
#  '935',
#  '9368',
#  '940',
#  '9433',
#  '9515',
#  '9544',
#  '976',
#  '9786',
#  '9902',
#  '9905']

# %%
i=0
for index, row in out.iterrows():
    pid = row['pathway_id']
    pathway = pathway_data[pathway_data['RandID'] == pid]
    pathway_randIDs = [str(int(float(rid))) for rid in pathway.columns[np.where(pathway == 1)[1]]]
    feat_path = list(set(pathway_randIDs).intersection(featureset_randIDs))
    a_df = pandas.DataFrame([[i, row['feature path count']]+feat_path], columns = [sim_type+'_'+centrality_type, 'n_features']+['rid_'+str(i) for i in range(len(feat_path))], index = [pid])
    all_out = all_out.append(a_df)
    i+=1

all_out
# Out:
#        correlation_degree correlation_page_rank heatkernel_degree  \
# p_1050                  0                   NaN               NaN
# p_174                   1                   NaN               NaN
# p_803                   2                   NaN               NaN
# p_2067                  3                   NaN               NaN
# p_206                   4                   NaN               NaN
# p_70                    5                   NaN               NaN
# p_2169                  6                   NaN               NaN
# p_1270                  7                   NaN               NaN
# p_614                   8                   NaN               NaN
# p_1273                  9                   NaN               NaN
# p_94                   10                   NaN               NaN
# p_2365                 11                   NaN               NaN
# p_143                  12                   NaN               NaN
#
#        heatkernel_page_rank n_features  rid_0  rid_1  rid_2  rid_3  rid_4  \
# p_1050                  NaN         14  24830   1121  21399  12371  15325
# p_174                   NaN         10   6965  26860  16243  31279  26646
# p_803                   NaN          7   7197  27568  31456    341  25781
# p_2067                  NaN          7  26860  16243  31279  26646   9251
# p_206                   NaN          5  31456    341  25781  31550  20050
# p_70                    NaN          5  25719  11794  16847  11015   4475
# p_2169                  NaN          5  30321  31558  29800   2059  18057
# p_1270                  NaN          5  30321  31558  29800   2059  18057
# p_614                   NaN          5  24830   1121  30471   7451  33772
# p_1273                  NaN          4  11015  16847  11794   4475    NaN
# p_94                    NaN          4  30321  18057   2059  31558    NaN
# p_2365                  NaN          4  30321  18057   2059  31558    NaN
# p_143                   NaN          4  30321  18057   2059  31558    NaN
#
#         ... rid_30 rid_31 rid_32 rid_33 rid_34 rid_35 rid_36 rid_37 rid_38  \
# p_1050  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_174   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_803   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2067  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_206   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_70    ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2169  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1270  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_614   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1273  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_94    ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2365  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_143   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        rid_39
# p_1050    NaN
# p_174     NaN
# p_803     NaN
# p_2067    NaN
# p_206     NaN
# p_70      NaN
# p_2169    NaN
# p_1270    NaN
# p_614     NaN
# p_1273    NaN
# p_94      NaN
# p_2365    NaN
# p_143     NaN
#
# [13 rows x 45 columns]

# %%
for sim_type, centrality_type in zip(['correlation', 'heatkernel', 'heatkernel'], ['page_rank', 'degree', 'page_rank']):
    if sim_type == 'heatkernel' and centrality_type =='degree':
        alpha = .1
    else:
        alpha = .05

    if centrality_type =='degree':
        sort_col = 'max degree norm'
    else:
        sort_col = 'unnormalized'


    epsilon = .00001
    
    out = pandas.read_csv(centrality_type+'_'+sim_type+'_'+str(epsilon)+'_'+str(alpha)+'.csv').sort_values(sort_col, ascending = False)

    i=0
    for index, row in out.iterrows():
        pid = row['pathway_id']
        if pid in list(all_out.index):
            all_out[sim_type+'_'+centrality_type][pid] = i
        else:
            pathway = pathway_data[pathway_data['RandID'] == pid]
            pathway_randIDs = [str(int(float(rid))) for rid in pathway.columns[np.where(pathway == 1)[1]]]
            feat_path = list(set(pathway_randIDs).intersection(featureset_randIDs))
            a_df = pandas.DataFrame([[i, row['feature path count']]+feat_path], columns = [sim_type+'_'+centrality_type, 'n_features']+['rid_'+str(i) for i in range(len(feat_path))], index = [pid])
            all_out = all_out.append(a_df)
        i+=1

# %%
all_out= all_out.sort_index()
all_out
# Out:
#        correlation_degree correlation_page_rank heatkernel_degree  \
# p_1050                  0                     0               NaN
# p_1270                  7                     7               NaN
# p_1273                  9                    11               NaN
# p_1274                NaN                   NaN                 7
# p_143                  12                    12               NaN
# p_1452                NaN                   NaN                 0
# p_1639                NaN                    13               NaN
# p_174                   1                     1                 1
# p_206                   4                     5                 5
# p_2067                  3                     3                 3
# p_2169                  6                     4               NaN
# p_2365                 11                    10               NaN
# p_501                 NaN                   NaN                 9
# p_614                   8                     8                 8
# p_70                    5                     6                 6
# p_803                   2                     2                 4
# p_884                 NaN                   NaN                 2
# p_94                   10                     9               NaN
#
#        heatkernel_page_rank n_features  rid_0  rid_1  rid_2  rid_3  rid_4  \
# p_1050                    0         14  24830   1121  21399  12371  15325
# p_1270                    7          5  30321  31558  29800   2059  18057
# p_1273                   10          4  11015  16847  11794   4475    NaN
# p_1274                  NaN          3  30471   7451  33772    NaN    NaN
# p_143                    12          4  30321  18057   2059  31558    NaN
# p_1452                  NaN         13   6965  16243  26860   3589  31279
# p_1639                   13          4  30321   2059  32735  31558    NaN
# p_174                     1         10   6965  26860  16243  31279  26646
# p_206                     4          5  31456    341  25781  31550  20050
# p_2067                    3          7  26860  16243  31279  26646   9251
# p_2169                    5          5  30321  31558  29800   2059  18057
# p_2365                   11          4  30321  18057   2059  31558    NaN
# p_501                   NaN          2  20050  25781    NaN    NaN    NaN
# p_614                     8          5  24830   1121  30471   7451  33772
# p_70                      6          5  25719  11794  16847  11015   4475
# p_803                     2          7   7197  27568  31456    341  25781
# p_884                   NaN         12  16243  26860   3589  31279  26646
# p_94                      9          4  30321  18057   2059  31558    NaN
#
#         ... rid_30 rid_31 rid_32 rid_33 rid_34 rid_35 rid_36 rid_37 rid_38  \
# p_1050  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1270  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1273  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1274  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_143   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1452  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_1639  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_174   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_206   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2067  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2169  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_2365  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_501   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_614   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_70    ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_803   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_884   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# p_94    ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        rid_39
# p_1050    NaN
# p_1270    NaN
# p_1273    NaN
# p_1274    NaN
# p_143     NaN
# p_1452    NaN
# p_1639    NaN
# p_174     NaN
# p_206     NaN
# p_2067    NaN
# p_2169    NaN
# p_2365    NaN
# p_501     NaN
# p_614     NaN
# p_70      NaN
# p_803     NaN
# p_884     NaN
# p_94      NaN
#
# [18 rows x 45 columns]
